# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./out/default/plot_data')

# 折れ線グラフを出力
plt.ylabel('corpus_count')
plt.xlabel('relative_time')
left = np.array(df['# relative_time'])
height = np.array(df[' corpus_count'])
plt.plot(left, height)
plt.show()
